# %% [markdown]
# LeetCode 42
#
# 알고리즘 인터뷰 7-2 <빗물 트래핑>

# %%
#높이를 입력받아 비 온 후 얼마나 많은 물이 쌓일 수 있는지 계산하라
#입력: [0,1,0,2,1,0,1,3,2,1,2,1]
#출력: 6

# %%
rainfall=input('높이를 입력: ')
rainfall

# %%
height = [int(i) for i in rainfall.split(',')]
height
# Out:
# [0, 1, 0, 2, 1, 0, 1, 3, 2, 1, 2, 1]

# %%
#1이상인 인덱스 i에 대해, i 양옆 인덱스에 들어간 값과 비교, 양 옆이 i보다 큰 경우 찾기
trap=[]
for i in range(1,len(height)-1):
  if height[i]<height[i-1] and height[i]<height[i+1]:
    print("%d~%d"%(i-1,i+1), end=" ")
    print(height[i-1:i+2])
# Out:
# 1~3 [1, 0, 2]
# 4~6 [1, 0, 1]
# 8~10 [2, 1, 2]
